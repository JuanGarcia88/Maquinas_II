# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanGarcia88/Maquinas_II/blob/main/TALLER_1C_MAQUINAS_ASINCRONAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import cmath

# %%
## MEZCLADORA
TmN = 120.54
Vel = 3565

# %%
Speed = np.linspace(0, 901, 100)
Sn_plot=(900-Speed)/900

f=60
Rs = 0.1729
Xs = (2*np.pi*f)*(1.3856*(10**-3))
Xm1 = (2*np.pi*f)*(38.4525*(10**-3))
R1 = 0.3928
X1 = (2*np.pi*f)*(6.5173*(10**-3))
R2 = 0.3928
X2 = (2*np.pi*f)*((1.3856*10**-3))
Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)
Ws = 94.24777960769379
Vth0 = 366.75900203560786
Rth0 = 0.16106061930589613
Xth0 = 0.5060450381022743
Te_PLOT = (((3*(Vth0**2))*(Rr_plot/Sn_plot))/((Ws*((Rth0 + (Rr_plot/Sn_plot))**2+((Xth0 + Xr_plot)**2)))))

indice_interseccion = np.argmin(np.abs(Te_PLOT - TmN))
velocidad_interseccion = Speed[indice_interseccion]+2
plt.figure(figsize=(11, 8))
plt.plot(Speed, Te_PLOT)
plt.xlabel('Velocidad del Motor (Speed)')
plt.ylabel('Torque electrico (Te)')
plt.title('Torque vs. Velocidad del Motor')
plt.axhline(y=TmN, xmax=882, linestyle='--', color='orange')
plt.scatter(880, 457.1868188533887, marker= 'x', color='green', label = 'Torque nominal maquina')
plt.scatter(velocidad_interseccion, TmN, marker= 'o', color='purple', label =f': {TmN:.2f}, {velocidad_interseccion:.2f}')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
TmN_min = TmN * (10/100)
TmN_Max = TmN * (150/100)

# %%
Speed = np.linspace(0, 901, 100)
Sn_plot=(900-Speed)/900

f=60
Rs = 0.1729
Xs = (2*np.pi*f)*(1.3856*(10**-3))
Xm1 = (2*np.pi*f)*(38.4525*(10**-3))
R1 = 0.3928
X1 = (2*np.pi*f)*(6.5173*(10**-3))
R2 = 0.3928
X2 = (2*np.pi*f)*((1.3856*10**-3))
Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)
Ws = 94.24777960769379
Vth0 = 366.75900203560786
Rth0 = 0.16106061930589613
Xth0 = 0.5060450381022743
Te_PLOT = (((3*(Vth0**2))*(Rr_plot/Sn_plot))/((Ws*((Rth0 + (Rr_plot/Sn_plot))**2+((Xth0 + Xr_plot)**2)))))

indice_interseccion = np.argmin(np.abs(Te_PLOT - TmN))
velocidad_interseccion = Speed[indice_interseccion]+2

indice_interseccion1 = np.argmin(np.abs(Te_PLOT - TmN_min))
velocidad_interseccion1 = Speed[indice_interseccion1]-1.89

indice_interseccion2 = np.argmin(np.abs(Te_PLOT - TmN_Max))
velocidad_interseccion2 = Speed[indice_interseccion2]

plt.figure(figsize=(11, 8))
plt.plot(Speed, Te_PLOT)
plt.xlabel('Velocidad del Motor (Speed)')
plt.ylabel('Torque electrico (Te)')
plt.title('Torque vs. Velocidad del Motor')
plt.axhline(y=TmN, xmax=900, linestyle='--', color='orange', label = 'Carga nominal')
plt.axhline(y=TmN_min, xmax=882, linestyle='--', color='purple', label = 'Carga minima')
plt.axhline(y=TmN_Max, xmax=882, linestyle='--', color='red', label = 'Carga maxima')
plt.scatter(880, 457.1868188533887, marker= 'x', color='green', label = 'Torque nominal maquina')
plt.scatter(velocidad_interseccion, TmN, marker= 'x', color='Orange', label =f': {TmN:.2f}, {velocidad_interseccion:.2f}')
plt.scatter(velocidad_interseccion1, TmN_min, marker= 'x', color='purple', label =f': {TmN_min:.2f}, {velocidad_interseccion1:.2f}')
plt.scatter(velocidad_interseccion2, TmN_Max, marker= 'x', color='red', label =f': {TmN_Max:.2f}, {velocidad_interseccion2:.2f}')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
## a minima carga

Sn0 = (900 - 893.90 ) / 900
print(Sn0)
# Out:
# 0.006777777777777803

# %%
Rr_min = (R1*R2*(R1+R2)+Sn0**2*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+Sn0**2*(X1+X2)**2)
Xr_min = (R1**2 * X2 + R2**2 * X1 + Sn0**2 * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + Sn0**2 * (X1 + X2)**2)

# %%
pp1=(1j*Xm1*((Rr_min/Sn0)+1j*Xr_min))/(1j*Xm1+((Rr_min/Sn0)+1j*Xr_min))
Zeq_min=Rs+1j*Xs+(pp1)
r0, theta0 = abs(Zeq_min), cmath.phase(Zeq_min)
print(Zeq_min)
print(f"Forma polar: {r0}∠{theta0} ")
# Out:
# (5.852543111838492+12.032155513415026j)
# Forma polar: 13.38002343700981∠1.118080891962633

# %%
Ie_min = 380/r0
print(Ie_min)
# Out:
# 28.4005481596468

# %%
Pin_N_min = (3 * 380 * Ie_min) * (np.cos(theta0))
print(Pin_N_min)
# Out:
# 14161.828187134308

# %%
Pcu_E_min = (3 * (Ie_min**2) * Rs )
print(Pcu_E_min)
# Out:
# 418.378822123078

# %%
Vth = 380*(((Xm1)/((Rs**2)+((Xs+Xm1)**2))**0.5))
print(Vth)
# Out:
# 366.75900203560786

# %%
Zth = (((complex(0, Xm1))*(Rs + complex(0, Xs))/(Rs + (complex(0, Xs)+ complex(0, Xm1)))))
Rth = Zth.real
Xth = Zth.imag

# %%
Ws = ((2*np.pi)/60)*900
print(Ws)
# Out:
# 94.24777960769379

# %%
Te_N = (((3*(Vth**2))*(Rr_min/Sn0))/((Ws*((Rth + (Rr_min/Sn0))**2+((Xth + Xr_min)**2)))))
print(Te_N)
# Out:
# 145.8225267716472
